# %% [markdown]
# <a href="https://colab.research.google.com/github/samuelvillegasc-cell/Ejercicios-Introducci-n-Ing.-Sistemas-Samuel-Villegas/blob/main/Ejercicios_Introducci%C3%B3n_Ing_Sistemas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
SUMA = 0
X = 20

SUMA = SUMA + X
Y = 40
X = X + Y ** 2
SUMA = SUMA + X / Y

print("EL VALOR DE LA SUMA ES:", SUMA)
# Out:
# EL VALOR DE LA SUMA ES: 60.5
